# %%
import duckdb
from sklearn.preprocessing import LabelEncoder
import os
import numpy as np
import torch
import argostranslate.package
import argostranslate.translate
import threading
from multiprocessing import cpu_count
from concurrent.futures import ThreadPoolExecutor
import subprocess
from textsum.summarize import Summarizer
import gc

# %%
num_cores = cpu_count()
print(f"Quantidade de núcleos: {num_cores}")
# Out:
# Quantidade de núcleos: 8

# %%
# Conectar (ou criar) um banco de dados
con = duckdb.connect(database='jus.duckdb', read_only=False)

# %%
# Download and install Argos Translate package
argostranslate.package.update_package_index()
available_packages = argostranslate.package.get_available_packages()
package_to_install = next(
    filter(
        lambda x: x.from_code == "pt" and x.to_code == "en", available_packages
    )
)
argostranslate.package.install_from_path(package_to_install.download())

# Translate
translatedText = argostranslate.translate.translate("Quais são os benefícios de banana ?", "pt", "en")
print(translatedText)
# Out:
# What are the benefits of banana?

# %%
con.execute("""
DELETE FROM metadadosPublicacao202202 WHERE teor NOT IN ('Concedendo', 'Negando') or teor IS NULL;
""")

# %%
data = con.execute("SELECT seqDocumento FROM metadadosPublicacao202202").fetchnumpy()
data["seqDocumento"]
# Out:
# array([144948780, 145620297, 139579332, ..., 142924179, 145440916,
#        144826578])

# %%
data["seqDocumento"].size
# Out:
# 35404

# %%
def process_file(file_info):
    file_path, file_id = file_info
    with open(file_path, 'r') as f:
        content = f.read()
        translatedText = argostranslate.translate.translate(content, "pt", "en")
        try:
          con.execute('INSERT INTO decisions_description (id,content) VALUES (?,?)', (int(file_id), translatedText))
          con.commit()
          print(file_id)
        except Exception as e:
          if 'violates primary key constraint' in str(e):
            print("Duplicate key, ignoring.",file_id)
          else:
            raise

# %%
file_paths = []  # para armazenar os caminhos completos dos arquivos
file_names = []  # para armazenar apenas os nomes dos arquivos

# caminhando através do diretório raiz e todos os seus subdiretórios
for dirpath, dirnames, filenames in os.walk('./data/202202-stj/', topdown=True):
    for filename in filenames:
        if filename.endswith('.txt'):
            full_path = os.path.join(dirpath, filename)
            file_paths.append(full_path)
            file_names.append(int(filename.split('.')[0]))

file_names = set(file_names)

# %%
for index,doc in enumerate(data["seqDocumento"]):
  if doc in file_names:
    process_file((file_paths[index], doc))
# Out:
# 144948780
# 145620297
# 139579332
# 141816757
# 144148942
# 145620328
# 141146541
# 146151036
# 145620304
# 145620331
# 145729863
# 145620309
# 144978248
# Duplicate key, ignoring. 144978248
# 140420607
# 141047357
# 145049821
# 142079128
# 140023292
# Duplicate key, ignoring. 140023292
# 146136272
# 145049828
# 143486995
# 141842062
# 146136290
# 146151023
# 145716661
# 145620339
# 145049802
# 145049781
# 146136286
# 144978242
# 144978249
# 143075799
# 145716678
# 146136277
# 146136294
# 144462665
# 145620310
# 142870194
# 143035920
# 146182571
# 145142820
# Duplicate key, ignoring. 141279576
# 144998370
# 142345836
# 144978245
# 145620312
# 145729878
# 145029208
# 137913170
# 145580002
# 145620319
# 145620324
# 145620301
# 116453450
# 146136271
# 146151030
# 140920370
# 146136275
# 140395973
# Duplicate key, ignoring. 140395973
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 for index,doc in enumerate(data["seqDocumento"]):
#       2   if doc in file_names:
# ----> 3     process_file((file_paths[index], doc))
#
# Cell In[11], line 5, in process_file(file_info)
#       3 with open(file_path, 'r') as f:
#       4     content = f.read()
# ----> 5     translatedText = argostranslate.translate.translate(content, "pt", "en")
#       6     try:
#       7       con.execute('INSERT INTO decisions_description (id,content) VALUES (?,?)', (int(file_id), translatedText))
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/argostranslate/translate.py:669, in translate(q, from_code, to_code)
#     658 """Translate a string of text
#     659
#     660 Args:
#    (...)
#     666     The translated text
#     667 """
#     668 translation = get_translation_from_codes(from_code, to_code)
# --> 669 return translation.translate(q)
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/argostranslate/translate.py:62, in ITranslation.translate(self, input_text)
#      52 def translate(self, input_text: str) -> str:
#      53     """Translates a string from self.from_lang to self.to_lang
#      54
#      55     Args:
#    (...)
#      60
#      61     """
# ---> 62     return self.hypotheses(input_text, num_hypotheses=1)[0].value
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/argostranslate/translate.py:295, in CachedTranslation.hypotheses(self, input_text, num_hypotheses)
#     289 # If len() of our cached items are different than `num_hypotheses` it means that
#     290 # the search parameter is changed by caller, so we can't re-use cache, and should update it.
#     291 if (
#     292     translated_paragraph is None
#     293     or len(translated_paragraph) != num_hypotheses
#     294 ):
# --> 295     translated_paragraph = self.underlying.hypotheses(
#     296         paragraph, num_hypotheses
#     297     )
#     298 new_cache[paragraph] = translated_paragraph
#     299 translated_paragraphs.append(translated_paragraph)
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/argostranslate/translate.py:172, in PackageTranslation.hypotheses(self, input_text, num_hypotheses)
#     169 translated_paragraphs = []
#     170 for paragraph in paragraphs:
#     171     translated_paragraphs.append(
# --> 172         apply_packaged_translation(
#     173             self.pkg, paragraph, self.translator, num_hypotheses
#     174         )
#     175     )
#     176 info("translated_paragraphs:", translated_paragraphs)
#     178 # Construct new hypotheses using all paragraphs
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/argostranslate/translate.py:424, in apply_packaged_translation(pkg, input_text, translator, num_hypotheses)
#     416 elif settings.stanza_available:
#     417     stanza_pipeline = stanza.Pipeline(
#     418         lang=pkg.from_code,
#     419         dir=str(pkg.package_path / "stanza"),
#    (...)
#     422         logging_level="WARNING",
#     423     )
# --> 424     stanza_sbd = stanza_pipeline(input_text)
#     425     sentences = [sentence.text for sentence in stanza_sbd.sentences]
#     426 else:
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/stanza/pipeline/core.py:166, in Pipeline.__call__(self, doc)
#     163 def __call__(self, doc):
#     164     assert any([isinstance(doc, str), isinstance(doc, list),
#     165                 isinstance(doc, Document)]), 'input should be either str, list or Document'
# --> 166     doc = self.process(doc)
#     167     return doc
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/stanza/pipeline/core.py:160, in Pipeline.process(self, doc)
#     158 for processor_name in PIPELINE_NAMES:
#     159     if self.processors.get(processor_name):
# --> 160         doc = self.processors[processor_name].process(doc)
#     161 return doc
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/stanza/pipeline/tokenize_processor.py:83, in TokenizeProcessor.process(self, document)
#      81     batches = DataLoader(self.config, input_data=data, vocab=self.vocab, evaluation=True)
#      82 else:
# ---> 83     batches = DataLoader(self.config, input_text=raw_text, vocab=self.vocab, evaluation=True)
#      84 # get dict data
#      85 _, _, _, document = output_predictions(None, self.trainer, batches, self.vocab, None,
#      86                        self.config.get('max_seqlen', TokenizeProcessor.MAX_SEQ_LENGTH_DEFAULT),
#      87                        orig_text=raw_text,
#      88                        no_ssplit=self.config.get('no_ssplit', False))
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/stanza/models/tokenize/data.py:61, in DataLoader.__init__(self, args, input_files, input_text, input_data, vocab, evaluation)
#      58     else:
#      59         labels = '\n\n'.join(['0' * len(pt.rstrip()) for pt in NEWLINE_WHITESPACE_RE.split(text)])
# ---> 61     self.data = [[(WHITESPACE_RE.sub(' ', char), int(label)) # substitute special whitespaces
#      62             for char, label in zip(pt.rstrip(), pc) if not (args.get('skip_newline', False) and char == '\n')] # check if newline needs to be eaten
#      63             for pt, pc in zip(NEWLINE_WHITESPACE_RE.split(text), NEWLINE_WHITESPACE_RE.split(labels)) if len(pt.rstrip()) > 0]
#      65 # remove consecutive whitespaces
#      66 self.data = [filter_consecutive_whitespaces(x) for x in self.data]
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/stanza/models/tokenize/data.py:61, in <listcomp>(.0)
#      58     else:
#      59         labels = '\n\n'.join(['0' * len(pt.rstrip()) for pt in NEWLINE_WHITESPACE_RE.split(text)])
# ---> 61     self.data = [[(WHITESPACE_RE.sub(' ', char), int(label)) # substitute special whitespaces
#      62             for char, label in zip(pt.rstrip(), pc) if not (args.get('skip_newline', False) and char == '\n')] # check if newline needs to be eaten
#      63             for pt, pc in zip(NEWLINE_WHITESPACE_RE.split(text), NEWLINE_WHITESPACE_RE.split(labels)) if len(pt.rstrip()) > 0]
#      65 # remove consecutive whitespaces
#      66 self.data = [filter_consecutive_whitespaces(x) for x in self.data]
#
# File ~/anaconda3/envs/py/lib/python3.10/site-packages/stanza/models/tokenize/data.py:62, in <listcomp>(.0)
#      58     else:
#      59         labels = '\n\n'.join(['0' * len(pt.rstrip()) for pt in NEWLINE_WHITESPACE_RE.split(text)])
#      61     self.data = [[(WHITESPACE_RE.sub(' ', char), int(label)) # substitute special whitespaces
# ---> 62             for char, label in zip(pt.rstrip(), pc) if not (args.get('skip_newline', False) and char == '\n')] # check if newline needs to be eaten
#      63             for pt, pc in zip(NEWLINE_WHITESPACE_RE.split(text), NEWLINE_WHITESPACE_RE.split(labels)) if len(pt.rstrip()) > 0]
#      65 # remove consecutive whitespaces
#      66 self.data = [filter_consecutive_whitespaces(x) for x in self.data]
#
# KeyboardInterrupt:

# %%
# Preparar lista de tarefas
tasks = []

for index,doc in enumerate(data["seqDocumento"]):
  if doc in file_names:
    tasks.append((file_paths[index], doc))

with ThreadPoolExecutor() as executor:
    results = list(executor.map(process_file, tasks))

# %%
con.close()
